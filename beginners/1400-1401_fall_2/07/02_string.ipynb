# %%
"""
name
value
type
"""

s = "hello WorLd To student"

# variable.(method name)

# capatalize
# re-assign
# s = s.capitalize()
#s1 = s.capitalize()

# uppercase the first letter and lower others
# Hello world to student
print(s.capitalize())

print(s.upper())
print(s.lower())

#
print(s.count('l'))
print(s.count('L'))
print(s.count('student'))
print("-----------------")

#                     15
# s = "hello WorLd To student"
print(s.endswith('student')) 
print(s.endswith('stu')) 
print(s.endswith('t')) 
print(s.endswith('ent')) 

# 
print(s.startswith("hello"))
print(s.startswith("h"))

# the first occurance of text
print(s.find("student"))
print(s.find("t")) # start from zero
#            search from index
print(s.find("t", 17))

# strings are Immutable 
# print(s.insert(0, "O"))


# 
print(s.title())

# %% [markdown]
# # Methods on string
#
#
#
#  - capitalize:
#     uppercase the first letter and lower the rest
#
#  - lower:
#     lowercase all letters
#
#  - upper:
#     uppercase all letters
#
#  - find:

# %%
a = "12"
b = "12c"
c = "12 "

# 
print(a.isdigit())
print(b.isdigit())
print(c.isdigit())
print("------------------")

# 
print(a.isalnum()) # contains character(alphabetic) OR digits
print(b.isalnum())
print(c.isalnum()) # space is not an alphabetic character
print("------------------")

# 
e = "HELLO"
f = "hello"
g = "Hello World"
h = "Hello world"
j = "      "
k = "a     a"

print(e.isupper()) # all characters must be uppercase
print(f.islower())
print(g.istitle())
print(h.istitle())
print(h.isspace())
print(j.isspace()) # all characters must be space
print(k[1: -1].isspace()) # True[1], False[0]

print("------------------")

m = "Hello\tWorld\t" # \t -> 4 spaces

# Hello	World	
print(m)
# Hello               World               
print(m.expandtabs(20))

# https://www.w3schools.com/python/ref_string_isnumeric.asp
n1 = "¾"
n2 = "-3"
n3 = ""
print(n1.isnumeric())
print(n2.isnumeric())
print("------------------")

# The zfill() method adds zeros (0) at the beginning of the string, until it reaches the specified length
# 0000000010
s = "10"
print(s.zfill(20)) # - - - - - - - - - - 1 0 
print(f"{int(s):020}")

print(f"{'name': >8}") # - - - - n a m e 
print(f"{'name': <8}") # n a m e - - - -

print(f"name:                    ")
print(f"math:\t{20}")
score = 'math: 20'
# print(f"{f'math: {20}': >16}") # n a m e - - - -
print(f"{score: >16}") # n a m e - - - -

# %%
#    012345678910
s = "Hello world"
# s = = s.replace('l', 'L')
s1 = s[:6] + s[6:].replace('l', 'L')

print(s)
print(s1)


# strip
print(s.find("Hello")) # from left to the right
print(s.find("l"))
print(s.rfind("l")) # positive index - from right to the left

c = "   Hello World    "
d = "****Hello*World****"
 
print(c.strip()) # default remove spaces from beginning and end of the string
print(d.strip('*'))
print(d.lstrip('*'))
print(d.rstrip('*'))

# split
f = "Hello world" # split/ separate the string according to space

#    Hello  world     to     student
g = "Hello*world*to*student"

print(f.split()) # default is space " "
print(g.split('*'))

# %% [markdown]
# # Oneline input
#
#
#
# ### Getting inputs from user in one line
#
#
# Instead of getting inputs in 4 lines
# ```python
# 12
# 13
# 14
# 15
# ```
# we can get inputs in oneline and split them with space
#
# ```python
# 12 13 14 15
#
# input().split()
# ```

# %%
# Oneline input

# 12 ENTER
# 13 ENTER
# 14 ENTER
# 15 ENTER

#  0  1  2  3
# 12 13 14 15 ENTER

s = input()

# 12 13 14 15
# 12, 13, 14, 15
# print(12, 13, 14, 15, sep=", ")
print(s, sep=", ")
print(s.split(), sep=", ")

# %%
# first input() execute
# then the value of last commant splitted

# fog => f(g(x))

# f(x) = x
# f(x).g(x) => x.get(x)

# input() => str
# str.method_name
#    str . method_name()
# "Hello world".split()
s = input().split()
print(s)
