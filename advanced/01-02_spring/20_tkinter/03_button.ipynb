# %% [markdown]
# # Button

# %%
from tkinter import *


# root
root = Tk()

# button
button = Button(root, text="Click me!")
button.pack()

# main eventloop
root.mainloop()

# %% [markdown]
# # Button on click

# %%
from tkinter import *


# root
root = Tk()


def on_click():
    print("CLicked!")


# button
button = Button(root, text="Click me!", command=on_click)
button.pack()

# main eventloop
root.mainloop()

# %% [markdown]
# # Update label's text on click

# %%
from tkinter import *


# root
root = Tk()


def on_click():
    global label

    label.configure(text="Hello again!") 


# button
button = Button(root, text="Click me!", command=on_click, pady=20, padx=20)
button.pack()

label = Label(root, text="Hello!")
label.pack()


# main eventloop
root.mainloop()

# %% [markdown]
# # Disable button

# %%
from tkinter import *


# root
root = Tk()


# button 
button = Button(root, text="Click me if you can!", font =('Verdana', 15), padx=10, pady=10, state=DISABLED)
button.pack(padx=10, pady=10)


# main eventloop
root.mainloop()
