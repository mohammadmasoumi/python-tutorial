# %% [markdown]
# # Markdown
#
# mark up language
#
#
# # Headers
#
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6
#
# # Quote
#
# > This is a quote
#
# # Code
#
# using back tick.
#
# ## Python
# ```python
# def function(a, b):
#     return a + b
# ```
#
# ## Bash
# ```bash
# pip install ipykernel
# ```
#
# ## C
# ```c
# int a;
# a = 12;
# printf("%d", a);
# ```
# ## Inline code
#
# This is `an inline code`.
#
# # Bold/Italic
#
# This is a **Bold** text.
#
# This is an *Italic* text.
#
#
# # Bullet point
#
# - first
# - second
#     - first of second
#     - second of second
# - third
#
# # Numeric items
#
# 1. first
# 2. second
#     1. first of second
#     2. second of second
# 3. third
#
# # Link
#
# [Github](https://github.com/mohammadmasoumi)
#
# [Github][1]
#
# [Github][a]
#
# [Github][github]
#
#
#
#
# [1]: https://github.com/mohammadmasoumi
# [a]: https://github.com/mohammadmasoumi
# [github]: https://github.com/mohammadmasoumi

# %% [markdown]
# # Extensions
#
# - Jupyter (interactive python notebook)
# - Ayu (Theme)
#     - Ayu mirage
# - Prettifier
#
# # Installation
#
# ```bash
# pip install ipykernel
# ```
# ## File suffix
#
# ```
# FILE.ipynb
# FILE.md
# ```
